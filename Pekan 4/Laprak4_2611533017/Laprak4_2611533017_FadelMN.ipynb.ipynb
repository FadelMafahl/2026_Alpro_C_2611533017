# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Conditional pada python”**
#
# **Disusun Oleh :**
#
# **Fadel Muhammad Naufal**
#
# **2611533017**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum yang telah dilaksanakan sebagai pertemuan ke-4 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan if, elif, else
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep if, elif, else, pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
#
# Fadel Muhammad  N
# 2611533017

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam pemrograman, komputer perlu mampu mengambil keputusan, bukan hanya menjalankan perintah secara berurutan. Untuk itu, digunakanlah conditional statement (pernyataan kondisional), yaitu struktur kontrol yang memungkinkan program menjalankan blok kode tertentu berdasarkan suatu kondisi. Konsep ini terinspirasi dari cara berpikir manusia dalam kehidupan sehari-hari, misalnya: "jika hujan, maka bawa payung; jika tidak, maka tidak perlu." Logika sederhana ini diterapkan dalam program melalui pernyataan if, elif, dan else. Dengan adanya struktur ini, program menjadi lebih fleksibel karena dapat merespons berbagai kemungkinan situasi, seperti validasi input, sistem penilaian, login, hingga logika pada aplikasi yang lebih kompleks. Oleh karena itu, pemahaman terhadap if, elif, dan else menjadi dasar penting dalam belajar pemrograman.
#
# ## 1.2 Tujuan
# 1. Mengetahui pengertian dan fungsi Statement Conditional.
# 2. Memahami jenis-jenis Statement Conditional.
# 3. Mengetahui cara membuat dan menggunakan variabel.
# 4. Mampu menggunakan Statement Conditional dalam membuat program sederhana.
# 5. Memahami cara menyimpan dan mengolah data dalam program
# ## 1.3 Manfaat
# 1. Mahasiswa memahami dasar-dasar pemrograman dengan lebih mudah.
# 1. Mahasiswa meningkatkan kemampuan berpikir logis dalam menyelesaikan masalah.
# 3. Mahasiswa mampu membuat program sederhana menggunakan Python.
# 4. Mahasiswa memahami cara menyimpan dan mengolah data dalam program.
# 5. Mahasiswa menjadi bekal untuk mempelajari pemrograman lebih lanjut.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Conditional merupakan struktur dalam Python yang digunakan untuk menjalankan perintah berdasarkan kondisi tertentu. Dengan conditional, program dapat menentukan apakah suatu perintah akan dijalankan atau tidak berdasarkan hasil evaluasi kondisi.
#
# 1. Pernyataan if Pernyataan if digunakan untuk menjalankan suatu perintah apabila kondisi yang diberikan bernilai benar (True). umur = 18
# 2. Pernyataan if-else Pernyataan if-else digunakan ketika terdapat dua kemungkinan kondisi. Jika kondisi pada if bernilai benar, maka perintah pada if dijalankan. Jika salah, program menjalankan perintah pada else.
# 3. Pernyataan if-elif-else if-elif-else digunakan ketika terdapat lebih dari dua kondisi yang perlu diperiksa. Python akan memeriksa kondisi secara berurutan hingga menemukan kondisi yang bernilai benar.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program if1_2611533017

# %%
ipk_3017 = float(input("input ipk anda = "))

if ipk_3017 > 2.75:
    print("Anda Lulus Sangat Memuaskan Dengan IPK" + str(ipk_3017))

print("program selsai")
# Out:
# Anda Lulus Sangat Memuaskan Dengan IPK4.0
# program selsai

# %% [markdown]
# **Penjelasan :**
# 1. Program dimulai dengan meminta pengguna memasukkan nilai IPK melalui fungsi input().
# 2. Nilai IPK yang dimasukkan diubah menjadi tipe data float agar dapat digunakan sebagai nilai numerik dalam perhitungan dan perbandingan.
# 3. Nilai tersebut disimpan ke dalam variabel ipk_3017.
# 4. Program memeriksa kondisi menggunakan pernyataan if, yaitu apakah nilai ipk_3017 lebih besar dari 2.75.
# 5. Jika kondisi tersebut benar, program menampilkan pesan “Anda Lulus Sangat Memuaskan dengan IPK” beserta nilai IPK yang dimasukkan.
# 6. Jika kondisi tersebut salah, program tidak menjalankan perintah di dalam if dan langsung melanjutkan ke perintah berikutnya.
# 7. Program menampilkan pesan “Program Selesai”.

# %% [markdown]
# ### 2.2.2 Program if2_2611533017

# %%
ipk_3017 = float(input("Input IPK Anda: "))

if ipk_3017 > 2.75:
    print("Anda lulus sangat memuaskan dengan IPK " + str(ipk_3017))
else:
    print("Anda tidak lulus")
print("Program selesai")
# Out:
# Anda tidak lulus
# Program selesai

# %% [markdown]
# **Penjelasan :**
#
# 1. Program dimulai dengan meminta pengguna memasukkan nilai IPK menggunakan fungsi input().
# 2. Nilai IPK yang dimasukkan diubah menjadi tipe data float agar dapat digunakan dalam proses perbandingan.
# 3. Nilai tersebut disimpan ke dalam variabel ipk_3017.
# 4. Program memeriksa kondisi if, yaitu apakah nilai ipk_3017 lebih besar dari 2.75.
# 5. Jika kondisi bernilai benar, program menampilkan pesan “Anda Lulus Sangat Memuaskan dengan IPK” beserta nilai IPK yang dimasukkan.
# 6. Jika kondisi bernilai salah, program menjalankan bagian else dan menampilkan pesan “Anda Tidak Lulus”.
# 7. Setelah proses percabangan selesai, program menampilkan pesan “Program Selesai”.

# %% [markdown]
# ### 2.2.3 Program Multi_if1_2611533017

# %%
umur_3017 = int(input("Masukkan umur anda: "))
sim_3017 = input("Apakah anda sudah punya sim C (y/t): ")[0]

if umur_3017 >= 17 and sim_3017 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")

if umur_3017 >= 17 and sim_3017 != 'y':
    print("Anda sudah dewasa tetapi tidak boleh bawa motor")

if umur_3017 < 17 and sim_3017 == 'y':
    print("Anda belum cukup umur punya sim")

if umur_3017 < 17 and sim_3017 != 'y':
    print("Anda belum cukup umur bawa motor")
# Out:
# Anda sudah dewasa dan boleh bawa motor

# %% [markdown]
# **Penjelasan :**
#
# 1. Program dimulai dengan meminta pengguna memasukkan umur menggunakan fungsi input().
# 2. Nilai umur diubah menjadi tipe data int dan disimpan dalam variabel umur_3017.
# 3. Program meminta pengguna memasukkan apakah sudah memiliki SIM dengan pilihan y atau t. Karakter pertama dari input diambil menggunakan [0] dan disimpan dalam variabel sim_3017.
# 4. Program memeriksa kondisi pertama, yaitu umur_3017 >= 17 dan sim_3017 == "y". Jika kedua kondisi benar, program menampilkan bahwa pengguna sudah dewasa dan boleh membawa motor.
# 5. Program memeriksa kondisi kedua, yaitu umur sudah 17 tahun atau lebih tetapi sim_3017 bukan "y". Jika benar, program menampilkan bahwa pengguna sudah dewasa tetapi tidak boleh membawa motor.
# 6. Program memeriksa kondisi ketiga, yaitu umur kurang dari 17 tahun dan sim_3017 bukan "y". Jika benar, program menampilkan bahwa pengguna belum cukup umur untuk membawa motor.
# 7. Program memeriksa kondisi keempat, yaitu umur kurang dari 17 tahun tetapi sim_3017 sama dengan "y". Jika benar, program menampilkan bahwa pengguna belum cukup umur untuk memiliki SIM.
# 8. Setelah seluruh kondisi diperiksa, program selesai.

# %% [markdown]
# ### 2.2.4 Program multi_if2_2611533017

# %%
total_belanja_3017 = float(input("Masukkan total belanja (Rp): "))

input_member_3017 = input("Apakah anda member? (y/t): ").strip().lower()
is_member_3017 = input_member_3017 in ["y", "yes"]

input_promo_3017 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_3017 = input_promo_3017 in ["y", "yes"]

total_diskon_3017 = 0

if total_belanja_3017 > 1000000:
    total_diskon_3017 += 10 # Diskon belanja besar

if is_member_3017:
    total_diskon_3017 += 5 # Diskon member

if kode_promo_valid_3017:
    total_diskon_3017 += 15 # Diskon voucher

nominal_diskon_3017 = total_belanja_3017 * (total_diskon_3017 / 100)
total_bayar_3017 = total_belanja_3017 - nominal_diskon_3017

print("\n--- Rincian pembayaran ---")
print(f"Total diskon: {total_diskon_3017}% (Rp {nominal_diskon_3017:,.0f})")
print(f"Total bayar : Rp {total_bayar_3017:,.0f}")

print(f"Total diskon yang anda dapatkan: {total_diskon_3017}%")
# output total diskon yang anda dapatkan: 30% jika belanja > 1 juta, member, dan kode promo valid
# Out:
# --- Rincian pembayaran ---
# Total diskon: 20% (Rp 20,000)
# Total bayar : Rp 80,000
# Total diskon yang anda dapatkan: 20%

# %% [markdown]
# **Penjelasan :**
#
# 1. Program dimulai dengan meminta pengguna memasukkan total belanja dalam rupiah menggunakan fungsi input().
# 2. Nilai total belanja diubah menjadi tipe data float dan disimpan dalam variabel total_belanja_3017.
# 3. Program meminta pengguna memasukkan status member dengan pilihan y atau t. Input kemudian diubah menjadi huruf kecil menggunakan .lower() dan spasi yang tidak diperlukan dihapus menggunakan .strip().
# 4. Program memeriksa apakah input member berupa "y" atau "t" menggunakan operator in. Hasil pemeriksaan disimpan dalam variabel is_member_3017.
# 5. Program meminta pengguna memasukkan status kode promo dengan pilihan y atau t. Input diproses dengan cara yang sama dan hasilnya disimpan dalam variabel kode_promo_valid_3017.
# 6. Variabel total_diskon_3017 diberikan nilai awal 0 sebagai tempat untuk menyimpan jumlah persentase diskon.
# 7. Program memeriksa kondisi pertama. Jika total belanja lebih dari Rp1.000.000, program menambahkan diskon sebesar 10%.
# 8. Program memeriksa kondisi kedua. Jika pengguna merupakan member, program menambahkan diskon sebesar 5%.
# 9. Program memeriksa kondisi ketiga. Jika kode promo dianggap valid, program menambahkan diskon sebesar 15%.
# 10. Karena menggunakan beberapa if yang terpisah, setiap kondisi diperiksa secara independen. Jika beberapa kondisi terpenuhi, persentase diskon akan diakumulasikan.
# 11. Program menghitung nominal diskon dengan mengalikan total belanja dengan persentase diskon yang telah diperoleh.
# 12. Program menghitung total pembayaran dengan mengurangi total belanja dengan nominal diskon.
# 13. Program menampilkan rincian pembayaran berupa total persentase diskon, nominal diskon dalam rupiah, dan total yang harus dibayar.
# 14. Program menampilkan kembali jumlah diskon yang diperoleh dalam bentuk persentase.

# %% [markdown]
# ### 2.2.5 Program if_elif_2611533017

# %%
umur_3017 = int(input("Input umur anda: "))
sim_3017 = input("Apakah anda sudah punya sim C (y/t): ")[0]

if umur_3017 >= 17 and sim_3017 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")

elif umur_3017 >= 17 and sim_3017 != 'y':
    print("Anda sudah dewasa tetapi tidak boleh bawa motor")

elif umur_3017 < 17 and sim_3017 == 'y':
    print("Anda belum cukup umur punya sim")

else:
    print("Anda belum cukup umur dan tidak boleh bawa motor")
print("Program selesai")
# Out:
# Anda sudah dewasa dan boleh bawa motor
# Program selesai

# %% [markdown]
# **Penjelasan :**
#
# 1. Program dimulai dengan meminta pengguna memasukkan umur menggunakan fungsi input().
# 2. Nilai umur diubah menjadi tipe data int dan disimpan dalam variabel umur_3017.
# 3. Program meminta pengguna memasukkan status kepemilikan SIM dengan pilihan y atau t. Karakter pertama dari input diambil menggunakan [0] dan disimpan dalam variabel sim_3017.
# 4. Program memeriksa kondisi pertama, yaitu apakah umur pengguna 17 tahun atau lebih dan memiliki SIM (sim_3017 == "y"). Jika kondisi benar, program menampilkan bahwa pengguna sudah dewasa dan boleh membawa motor.
# 5. Jika kondisi pertama salah, program memeriksa kondisi elif kedua, yaitu apakah umur pengguna 17 tahun atau lebih tetapi tidak memiliki SIM. Jika benar, program menampilkan bahwa pengguna sudah dewasa tetapi tidak boleh membawa motor.
# 6. Jika kondisi kedua juga salah, program memeriksa kondisi elif ketiga, yaitu apakah umur pengguna kurang dari 17 tahun tetapi memiliki SIM. Jika benar, program menampilkan bahwa pengguna belum cukup umur untuk memiliki SIM.
# 7. Jika seluruh kondisi sebelumnya salah, program menjalankan bagian else dan menampilkan bahwa pengguna belum cukup umur dan tidak boleh membawa motor.
# 8. Setelah salah satu kondisi terpenuhi, program menampilkan pesan "Program Selesai".

# %% [markdown]
# ### 2.2.6 Program nilai_2611533017

# %%
nilai_3017 = int(input("Inputkan nilai angka="))

if nilai_3017 >= 81:
    print("A")
elif nilai_3017 >= 70:
    print("B")
elif nilai_3017 >= 60:
    print("C")90
elif nilai_3017 >= 50:
    print("D")
else:
    print("E")
# Out:
# A

# %% [markdown]
# **Penjelasan :**
#
# 1. Program dimulai dengan meminta pengguna memasukkan nilai angka menggunakan fungsi input().
# 2. Nilai yang dimasukkan diubah menjadi tipe data int dan disimpan dalam variabel nilai_3017.
# 3. Program memeriksa kondisi pertama, yaitu apakah nilai lebih besar atau sama dengan 81. Jika benar, program menampilkan nilai A.
# 4. Jika kondisi pertama salah, program memeriksa kondisi elif kedua, yaitu apakah nilai lebih besar atau sama dengan 70. Jika benar, program menampilkan nilai B.
# 5. Jika kondisi kedua salah, program memeriksa kondisi elif ketiga, yaitu apakah nilai lebih besar atau sama dengan 60. Jika benar, program menampilkan nilai C.
# 6. Jika kondisi ketiga salah, program memeriksa kondisi elif keempat, yaitu apakah nilai lebih besar atau sama dengan 50. Jika benar, program menampilkan nilai D.
# 7. Jika seluruh kondisi sebelumnya salah, program menjalankan bagian else dan menampilkan nilai E.
# 8. Setelah salah satu kondisi terpenuhi, program selesai.

# %% [markdown]
# ### 2.2.7 Program match_case1_2611533017

# %%
bulan_3017 = int(input("Masukkan angka bulan (1 - 12): "))

match bulan_3017:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")
# Out:
# April

# %% [markdown]
# **Penjelasan :**
#
# 1. Program dimulai dengan meminta pengguna memasukkan angka bulan dari 1 sampai 12 menggunakan fungsi input().
# 2. Nilai yang dimasukkan diubah menjadi tipe data int dan disimpan dalam variabel bulan_3017.
# 3. Program menggunakan struktur match-case untuk mencocokkan nilai bulan_3017 dengan beberapa pilihan yang tersedia.
# 4. Jika nilai yang dimasukkan adalah 1, program menampilkan Januari.
# 5. Jika nilai 2 sampai 12, program menampilkan nama bulan yang sesuai, mulai dari Februari hingga Desember.
# 6. Jika angka yang dimasukkan tidak sesuai dengan angka 1 sampai 12, program menjalankan case _ dan menampilkan pesan "Angka tidak valid".
# 7. Setelah nama bulan atau pesan kesalahan ditampilkan, program selesai.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Conditional pada python merupakan salah satu struktur kontrol paling fundamental dalam pemrograman, yang memungkinkan sebuah program untuk "mengambil keputusan" dan menentukan blok kode mana yang akan dijalankan berdasarkan hasil evaluasi kondisi logika (True atau False), bukan berjalan secara linear dari atas ke bawah tanpa arah alternatif. Struktur ini dibangun dari tiga elemen utama yang saling melengkapi, yaitu if sebagai pemeriksa kondisi awal, elif sebagai penambah kemungkinan kondisi lain jika kondisi sebelumnya tidak terpenuhi, dan else sebagai blok penutup yang menampung seluruh kemungkinan yang tersisa. Ketiganya dapat dikombinasikan sesuai kebutuhan, mulai dari percabangan sederhana satu kondisi (if saja), dua kemungkinan (if-else), hingga banyak kemungkinan sekaligus (if-elif-else). Dalam proses eksekusinya, sistem selalu memeriksa kondisi secara berurutan dari atas ke bawah, dan begitu ditemukan satu kondisi yang bernilai True, blok kode terkait langsung dijalankan sementara seluruh kondisi lain yang tersisa akan diabaikan (bersifat eksklusif mutual). Karena sifat inilah, urutan penyusunan kondisi menjadi sangat penting dan harus disusun secara logis dan cermat, sebab urutan yang keliru dapat menghasilkan alur eksekusi program yang tidak sesuai dengan yang diharapkan.Untuk membentuk kondisi yang akan dievaluasi, conditional statement memanfaatkan dua kelompok operator, yaitu operator perbandingan (untuk membandingkan nilai) dan operator logika (untuk menggabungkan atau membalik beberapa kondisi sekaligus), sehingga memungkinkan pembuatan aturan pengambilan keputusan yang fleksibel dan kompleks sesuai kebutuhan program. Secara keseluruhan, pemahaman yang kuat terhadap conditional statement menjadi fondasi penting sebelum mempelajari konsep-konsep pemrograman yang lebih lanjut, seperti perulangan (looping) dan fungsi (function), karena hampir seluruh logika pengambilan keputusan dalam program — baik yang sederhana maupun kompleks — pada dasarnya dibangun di atas prinsip percabangan (branching) yang telah dijelaskan dalam teori ini.

# %% [markdown]
# ## Tugas

# %% [markdown]
# Studi Kasus: Sistem Loket Terpadu & Audit Transaksi Ekspedisi Wahana
# Sebuah wahana rekreasi petualangan membutuhkan sistem loket berbasis konsol untuk menentukan jenis wahana, memverifikasi kelaikan pengunjung dengan kondisi majemuk (logical operators), menghitung diskon akumulatif menggunakan multi-if terpisah, serta mencetak audit status operasional.
# Catatan Materi: Seluruh alur program disusun murni menggunakan 4 pilar percabangan yang diajarkan pada modul Pekan 4: (1) if tunggal, (2) if-else, (3) if-elif-else dengan operator logika (and, or, !=), (4) Multi-if terpisah untuk diskon akumulasi, dan (5) match-case (1 s.d. 5 beserta case _). Tidak ada nested-if (if di dalam if).

# %% [markdown]
# **Jawab :**

# %%
print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")

# 1. Input Data Pengunjung & String Handling
nama_3017 = input("Masukkan Nama Pengunjung        : ")
umur_3017 = int(input("Input umur anda                 : "))
sim_3017 = input("Apakah Anda Sudah Punya SIM C (y/t): ").strip().lower()

if len(sim_3017) > 0:
    sim_3017 = sim_3017[0]

print("\nPilihan Paket Wahana (1-5):")
print("  1. Safari Rimba         (Rp 50,000)")
print("  2. Arung Jeram          (Rp 75,000)")
print("  3. Motor ATV Ekstrim    (Rp 120,000)")
print("  4. Roller Coaster Kilat (Rp 100,000)")
print("  5. All-Access VIP       (Rp 220,000)")

paket_3017 = int(input("Masukkan nomor paket (1-5)      : "))
jumlah_tiket_3017 = int(input("Masukkan jumlah tiket           : "))

# Validasi if-tunggal untuk jumlah tiket
if jumlah_tiket_3017 <= 0:
    print("Peringatan: Jumlah tiket tidak valid!")
    exit()

is_member_3017 = input("Apakah Anda member? (y/t)       : ").strip().lower()
kode_promo_3017 = input("Apakah kode promo valid? (y/t)  : ").strip().lower()

# 2. Pemilihan Wahana Menggunakan match-case
nama_wahana_3017 = ""
harga_satuan_3017 = 0

match paket_3017:
    case 1:
        nama_wahana_3017 = "Wahana Safari Rimba"
        harga_satuan_3017 = 50000
    case 2:
        nama_wahana_3017 = "Wahana Arung Jeram"
        harga_satuan_3017 = 75000
    case 3:
        nama_wahana_3017 = "Wahana Motor ATV Ekstrim"
        harga_satuan_3017 = 120000
    case 4:
        nama_wahana_3017 = "Wahana Roller Coaster Kilat"
        harga_satuan_3017 = 100000
    case 5:
        nama_wahana_3017 = "Wahana All-Access VIP"
        harga_satuan_3017 = 220000
    case _:
        print("Paket wahana tidak valid!")
        exit()

# 3. Validasi Izin Kendali Wahana Menggunakan if-elif-else dan Operator Logika
print("\n--- KELAYAKAN PENGENDARA WAHANA ---")
status_akses_3017 = ""

if paket_3017 == 3 and umur_3017 >= 17 and sim_3017 == 'y':
    status_akses_3017 = "Anda sudah dewasa dan boleh mengendarai ATV sendiri."
elif paket_3017 == 3 and umur_3017 >= 17 and sim_3017 != 'y':
    status_akses_3017 = "Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur)."
elif paket_3017 == 3 and umur_3017 < 17 and sim_3017 == 'y':
    status_akses_3017 = "Identitas tidak valid: Belum cukup umur memiliki SIM."
elif paket_3017 == 3 and umur_3017 < 17 and sim_3017 != 'y':
    status_akses_3017 = "Anda belum cukup umur dan tidak boleh bawa motor ATV."
elif paket_3017 != 3 and umur_3017 >= 10:
    status_akses_3017 = "Anda memenuhi syarat umur untuk menikmati wahana ini."
else:
    status_akses_3017 = "Mohon maaf, umur Anda belum memenuhi batas minimal untuk wahana ini."

print(f"Status Akses: {status_akses_3017}")

# 4. Akumulasi Diskon Bertingkat Menggunakan Multi-IF Terpisah
subtotal_3017 = harga_satuan_3017 * jumlah_tiket_3017
total_diskon_persen_3017 = 0

if subtotal_3017 >= 200000:
    total_diskon_persen_3017 += 10

if is_member_3017 in ['y', 'ya']:
    total_diskon_persen_3017 += 5

if kode_promo_3017 in ['y', 'ya']:
    total_diskon_persen_3017 += 15

if jumlah_tiket_3017 >= 5:
    total_diskon_persen_3017 += 5

# 5. Hitung Total dan Evaluasi Audit (if-else)
nominal_diskon_3017 = subtotal_3017 * (total_diskon_persen_3017 / 100)
total_bayar_3017 = subtotal_3017 - nominal_diskon_3017

catatan_layanan_3017 = ""
if total_bayar_3017 > 300000:
    catatan_layanan_3017 = "Selamat! Anda berhak mendapatkan Souvenir Gratis."
else:
    catatan_layanan_3017 = "Terima kasih telah berkunjung."

# Output Rincian Pembayaran
print("\n--- Rincian Pembayaran ---")
print(f"Subtotal Belanja : Rp {subtotal_3017:,.0f}")
print(f"Total Diskon     : {total_diskon_persen_3017}% (Rp {nominal_diskon_3017:,.0f})")
print(f"Total Bayar      : Rp {total_bayar_3017:,.0f}")
print(f"Catatan Layanan  : {catatan_layanan_3017}")
print("Program Selesai")
# Out:
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
#
# Pilihan Paket Wahana (1-5):
#   1. Safari Rimba         (Rp 50,000)
#   2. Arung Jeram          (Rp 75,000)
#   3. Motor ATV Ekstrim    (Rp 120,000)
#   4. Roller Coaster Kilat (Rp 100,000)
#   5. All-Access VIP       (Rp 220,000)
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.
#
# --- Rincian Pembayaran ---
# Subtotal Belanja : Rp 120,000
# Total Diskon     : 0% (Rp 0)
# Total Bayar      : Rp 120,000
# Catatan Layanan  : Terima kasih telah berkunjung.
# Program Selesai

# %% [markdown]
# **Penjelasan :**
#
# 1. Pengolahan Input & Validasi Awal:
#
#     Meminta masukan data nama, umur, kepemilikan SIM C, paket wahana, jumlah tiket, serta status member dan kode promo.
#     Menggunakan metode .strip().lower() dan indexing [0] untuk pembersihan string input SIM C.
#     Menerapkan percabangan if tunggal untuk menghentikan program (exit()) jika jumlah tiket yang diinput bernilai <= 0.
# 2. Pemilihan Paket Wahana (match-case):
#
#     Memanfaatkan struktur match-case pada variabel paket_3017 untuk memetakan nama wahana dan harga satuan tiket secara efisien berdasarkan pilihan paket 1 hingga 5.
#     Pola default case _ menangani masukan paket yang tidak sesuai dengan daftar.
# 3. Validasi Kelayakan Pengendara (if-elif-else):
#
#     Menggunakan percabangan berantai if-elif-else yang digabungkan dengan operator logika (and, !=, ==, <) untuk mengevaluasi kelayakan khusus wahana ATV Ekstrim (Paket 3) berdasarkan syarat umur minimum 17 tahun dan kepemilikan SIM C.
# 4. Akumulasi Diskon Bertingkat (Multi-IF):
#
#     Memanfaatkan struktur Multi-IF independen untuk akumulasi diskon: syarat subtotal
#     Rp200.000 (+10%), status member (+5%), promo valid (+15%), dan pembelian grosir tiket
#     (+5%). Sifat Multi-IF memungkinkan diskon menumpuk hingga maksimal 35%.
#     Kalkulasi & Evaluasi Layanan (if-else):
#
# 5. Menghitung nilai rupiah diskon dan total biaya yang harus dibayar.
#     Menerapkan struktur if-else untuk mengevaluasi apakah total bayar >300.000
#     guna menentukan hak atas souvenir gratis.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# Python Software Foundation. (2024). The Python Tutorial — More Control Flow Tools.
# https://docs.python.org/3/tutorial/controlflow.html
# Python Software Foundation. (2024). The Python Language Reference — Compound Statements (if, match).
# https://docs.python.org/3/reference/compound_stmts.html
# W3Schools. (2024). Python Conditions and If statements.
# https://www.w3schools.com/python/python_conditions.asp
# GeeksforGeeks. (2024). Decision Making in Python (if, if..else, Nested if, if-elif).
# https://www.geeksforgeeks.org/decision-making-python-else-nested-elif/
# Real Python. (2024). Conditional Statements in Python.
# https://realpython.com/python-conditional-statements/
