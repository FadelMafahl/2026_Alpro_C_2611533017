# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Type Data dan Variabel”**
#
# **Disusun Oleh :**
#
# **Fadel Muhammad Naufal**
#
# **2611533017**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum ... yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan ...
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep ... pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, September 2026
#
#
# Fadel Muhammad Naufal

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemrograman merupakan salah satu kemampuan penting dalam bidang Informatika. Sebagai mahasiswa Informatika semester 1, pemahaman dasar pemrograman perlu dikuasai untuk menunjang pembelajaran selanjutnya. Salah satu konsep dasar yang perlu dipahami dalam bahasa pemrograman Python adalah tipe data dan variabel, karena keduanya digunakan dalam proses penyimpanan dan pengolahan data pada program.
#
# Dalam Python, terdapat berbagai tipe data seperti int, float, komplek, string, boolean, konstanta serta penggunaan input yang digunakan sesuai dengan jenis nilai yang akan diproses. Variabel digunakan untuk menyimpan atau mereferensikan nilai tersebut. Oleh karena itu, praktikum Tipe Data dan Variabel dilakukan untuk memberikan pemahaman dasar mengenai berbagai tipe data dan penggunaan variabel dalam bahasa pemrograman Python.
#
# ## 1.2 Tujuan
# 1. Mengetahui pengertian dan fungsi tipe data serta variabel.
# 2. Memahami jenis-jenis tipe data dalam Python.
# 3. Mengetahui cara membuat dan menggunakan variabel.
# 4. Mampu menggunakan tipe data dan variabel dalam membuat program sederhana.
# 5. Memahami cara menyimpan dan mengolah data dalam program
#
# ## 1.3 Manfaat
# 1. Mahasiswa memahami dasar-dasar pemrograman dengan lebih mudah.
# 2. Mahasiswa meningkatkan kemampuan berpikir logis dalam menyelesaikan masalah.
# 3. Mahasiswa mampu membuat program sederhana menggunakan Python.
# 4. Mahasiswa memahami cara menyimpan dan mengolah data dalam program.
# 5. Mahasiswa menjadi bekal untuk mempelajari pemrograman lebih lanjut.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Konsep-konsep utama mengenai tipe data dan variabel pada bahasa Python meliputi:
#
# 1. Variabel dan Dynamically Typed: Variabel adalah pemetaan nama yang menunjuk ke lokasi memori penampung nilai. Dalam Python, variabel tidak perlu dideklarasikan tipe datanya terlebih dahulu. Interpreter akan mengevaluasi tipe data secara otomatis saat alokasi nilai dilakukan.
#
# 2. Tipe Data Numerik: Python mendukung tiga jenis numerik utama:
#
# Integer (int): Bilangan bulat positif atau negatif tanpa koma desimal.
#
# Float (float): Bilangan riil berpresisi presisi ganda yang mengandung titik desimal.
#
# Complex (complex): Bilangan kompleks berbentuk a+bj, di mana a adalah bagian rill dan b adalah bagian imajiner.
#
# 3. Tipe Data String (string): Kumpulan karakter yang dibatasi oleh tanda petik tunggal ('), tanda petik ganda (\"), atau triple quotes (\"\"\" / '''). Tanda petik tiga memungkinkan penulisan teks multi-baris (multiline string) yang mempertahankan format spasi dan baris baru.
#
# 4. Tipe Data Boolean (bool): Tipe data logika yang hanya memiliki dua kemungkinan nilai, yaitu True atau False. Nilai boolean sering kali dihasilkan dari evaluasi ekspresi kondisi atau operator perbandingan (misalnya >=, <=, ==).
#
# 5. Input dan Type Casting: Fungsi input() digunakan untuk mengambil masukan dari pengguna secara interaktif melalui konsol. Karena keluaran bawaan fungsi input() selalu berbentuk String (string), maka diperlukan type casting menggunakan fungsi seperti int() atau float() agar nilai tersebut dapat dioperasikan secara matematis.
#
# 6. Konstanta dan String Formatting: Menurut standar konvensi PEP 8, konstanta dinyatakan dengan nama variabel berhuruf kapital. Dalam Python modern, kejelasan konstanta dipertegas dengan penanda Final dari modul typing. Untuk menampilkan nilai numerik atau konstanta secara rapi, digunakan string formatting (seperti operator % atau %f / %.2f)..

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Numerik_2611533017

# %%
#create a variable with numeric type value.
a_3017=100
print("The type of a variable having value",a_3017,"is",type(a_3017))

#create a variable with float value.
b_3017=10.2345
print("The type of variable having value",b_3017,"is",type(b_3017))

#create a variable with complex value.
c_3017=100+3j
print("The type of variable having value",c_3017,"is",type(c_3017))
# Out:
# The type of a variable having value 100 is <class 'int'>
# The type of variable having value 10.2345 is <class 'float'>
# The type of variable having value (100+3j) is <class 'complex'>

# %% [markdown]
# **Penjelasan :**
# 1. Deklarasi a_1021 dengan nilai 100 sebagai integer.
# 2. Cetak ("The type of variable having value",a_1021,"is",type(a_1021)) dengan type() digunakan untuk  mengetahui tipe variabel dari a_1021.
# 3. Deklarasi b_1021 dengan nilai 10.2345 sebagai float.
# 4. Cetak ("The type of variable having value",b_1021,"is",type(b_1021)) dengan type() digunakan untuk  mengetahui tipe variabel dari b_1021.
# 5. Deklarasi c_1021 dengan nilai (100 + 3j) sebagai komplek.
# 6. Cetak ("The type of variable having value",c_1021,"is",type(c_1021)) dengan type() digunakan untuk mengetahui tipe variabel dari c_1021

# %% [markdown]
# ### 2.2.2 Program String_2611533017

# %%
nama= "Fadel_3017"
jenis_kelamin= "Laki-laki"
alamat = """"
    Kampus Unand 
    kec.nanggalo
    kota padang
"""
agama= "islam"
print("Nama saya adalah", nama)
print("Jenis kelamin saya adalah", jenis_kelamin)
print("Alamat saya adalah", alamat)
print("Agama saya adalah", agama)
# Out:
# Nama saya adalah Fadel_3017
# Jenis kelamin saya adalah Laki-laki
# Alamat saya adalah "
#     Kampus Unand
#     kec.nanggalo
#     kota padang
#
# Agama saya adalah islam

# %% [markdown]
# **Penjelasan :**
#
# 1. Deklarasi nama = "Fadel_3017" sebagai string
# 2. Deklarasi jenis_kelamin = 'Laki-laki' sebagai string
# 3. Deklarasi alamat = """Kampus Unand, Kec. Nanggalo, Kota Padang""" sebagai string
# 4. Deklarasi agama = "Islam" sebagai string
# 5. Cetak ("Nama saya adalah: ", nama)
# 6. Cetak ("Jenis kelamin saya adalah: ", jenis_kelamin)
# 7. Cetak ("Alamat saya adalah: ", alamat)
# 8. Cetak ("Agama saya adalah: ", agama)

# %% [markdown]
# ## 2.2.3 Program Boolean_2611533017

# %%
is_lulus = True
is_cumlaude = True

nilai_3017 = 85
batas_lulus = 75

status_kelulusan = nilai_3017 >= batas_lulus #Hasilnya akan True

print("=== Check Kelulusan ===")
print("nilai:", nilai_3017)
print("Apakah lulus?:", status_kelulusan)
if is_lulus and is_cumlaude:
    print("Selamat, Anda lulus dengan predikat cumlaude")
# Out:
# === Check Kelulusan ===
# nilai: 85
# Apakah lulus?: True
# Selamat, Anda lulus dengan predikat cumlaude

# %% [markdown]
# **Penjelasan :**
#
# 1. Deklarasi is_lulus = True sebagai boolean
# 2. Deklarasi is_cumlaude = True sebagai boolean
# 3. Deklarasi nilai_3017 = 85 sebagai integer
# 4. Deklarasi batas_lulus = 75 sebagai integer
# 5. Deklarasi status_kelulusan = nilai_3017 >= batas_lulus sebagai boolean
# 6. Cetak ("=== Check Kelulusan ===")
# 7. Cetak ("Nilai: ",nilai_3017)
# 8. Cetak ("Apakah lulus?: ",status_kelulusan)
# 9. Jika is_lulus dan is_cumlaude bernilai benar cetak ("Selamat, Anda lulus dengan predikat Cum Laude!")

# %% [markdown]
# ## 2.2.4 Program Input_2611533017

# %%
panjang_3017 = input('masukkan panjang: ')
lebar_3017 = input('masukkan lebar: ')
luas_3017 = int(panjang_3017) * int(lebar_3017)
print("Luas =", luas_3017)
# Out:
# Luas = 100

# %% [markdown]
# **Penjelasan :**
#
# 1. Input nilai panjang_3017
# 2. Input nilai lebar_3017
# 3. Nilai luas_3017 = int(panjang_3017) * int(lebar_3017)
# 4. Cetak ("Luas = ",luas_3017)

# %% [markdown]
# ## 2.2.5 Program Konstanta_2611533017

# %%
from typing import Final
PI: Final = 3.14
print("pi: %f" % (PI))
jari_3017 = float(input('Masukkan nilai Jari-Jari: '))
luas_3017 = PI * jari_3017 * jari_3017
print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_3017, luas_3017))
# Out:
# pi: 3.140000
# Luas lingkaran dengan jari-jari 20.00 adalah 1256.00

# %% [markdown]
# **Penjelasan :**
#
# 1. Pemanggilan Final dari library typing from typing import Final
# 2. Deklarasi PI: Final = 3.14 sebagai konstanta
# 3. Cetak ("Pi: %f" % (PI))
# 4. Nilai jari_3017 = float(input("Masukkan nilai jari-jari: "))
# 5. Nilai luas_3017 = PI * jari_3017
# 6. Cetak ("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_1021,luas_3017))

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa tipe data dan variabel merupakan konsep dasar yang penting dalam pemrograman Python. Tipe data digunakan untuk menentukan jenis nilai yang akan diproses, seperti int, float, complek, string, bool, konstanta serta penggunaan input, sedangkan variabel digunakan untuk menyimpan atau mereferensikan nilai tersebut. Dengan memahami penggunaan tipe data dan variabel, mahasiswa dapat membuat program sederhana untuk menyimpan, mengolah, dan menampilkan data dengan lebih tepat serta menjadi dasar untuk mempelajari konsep pemrograman Python yang lebih lanjut.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# GitHub. (2026). About repositories. GitHub Docs. https://docs.github.com/en/repositories/creating-and-managing-repositories/about-repositories
#
# Microsoft. (2026). Python in Visual Studio Code. Visual Studio Code Documentation. https://code.visualstudio.com/docs/languages/python
#
# Python Software Foundation. (2026). Built-in Types — Python Documentation. Python Documentation. https://docs.python.org/3/library/stdtypes.html
#
# Python Software Foundation. (2026). The Python Tutorial. Python Documentation. https://docs.python.org/3/tutorial/
